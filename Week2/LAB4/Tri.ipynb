# %%
t1 = []
t2 = []

def tri(t):
      
    
    if len(t) <= 1:
        return t
    
    if len(t) > 1: 
        p = 0
        for i in t[1:]:
            print('i:',i)
            if i < t[p]:
                t1.append(i)
                print('t1:',t1)
            if i >= t[p]:
                t2.append(i)
                print('t2:',t2)
        return  tri(t1)+[t[p]]+ tri(t2)


def tri_rapide(t):
    if len(t) <= 1:
        return t
    else:
        pivot = 0
        g = [x  for x in t[1:] if x < t[pivot]]
        d = [x for x in t[1:] if x >= t[pivot]]
        return tri_rapide(g)+[t[pivot]]+tri_rapide(d)



def tri_gauche(t):
     
    
    if len(t) <= 1:
        return t
    
    else: 
        p = int(len(t)/2)
        for i in range(1,len(t)):
            if t[i] < t[p]:
                t1.append(t[i])
        
    return  tri_gauche(t1)+[t[p]]+ tri_droite(t1)
            
    
def tri_droite(t):
    p = int(len(t)/2)
    
    
    if len(t) <= 1:
        return t
    
    else: 
        for i in range(1,len(t)):
            if t[i] >= t[p]:
                t2.append(t[i])
        
    return  tri_gauche(t2)+[t[p]]+ tri_droite(t2)
            

def fusion(t1,t2):
    t2=[]
    t1=[]
    p = int(len(t)/2)
    
    t=t1.extend(t2)
    return t

# %%
d =[8,2,12]

# %%
r=tri(d)
# Out:
# i: 2
# t1: [2]
# i: 12
# t2: [12, 12]
# i: 12
# t2: [12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# t2: [12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12]
# i: 12
# ...

# %%
r
# Out:
# [8, 12]

# %%
l=[4,2,33,0,9,1,2,5]

# %%
tri_rapide(l)
# Out:
# [0, 1, 2, 2, 4, 5, 9, 33]

# %%
tri(l)
# Out:
# [33, 9, 33]
