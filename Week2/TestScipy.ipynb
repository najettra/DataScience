# %%
from numpy import *
import scipy as sp
from scipy import linalg
import matplotlib.pyplot as plt
from scipy import stats
dir(stats)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_binned_statistic',
#  '_constants',
#  '_continuous_distns',
#  '_discrete_distns',
#  '_distn_infrastructure',
#  '_distr_params',
#  '_multivariate',
#  '_stats',
#  '_stats_mstats_common',
#  '_tukeylambda_stats',
#  'absolute_import',
#  'alpha',
#  'anderson',
#  'anderson_ksamp',
#  'anglit',
#  'ansari',
#  'arcsine',
#  'argus',
#  'bartlett',
#  'bayes_mvs',
#  'bernoulli',
#  'beta',
#  'betaprime',
#  'binned_statistic',
#  'binned_statistic_2d',
#  'binned_statistic_dd',
#  'binom',
#  'binom_test',
#  'boltzmann',
#  'boxcox',
#  'boxcox_llf',
#  'boxcox_normmax',
#  'boxcox_normplot',
#  'bradford',
#  'burr',
#  'burr12',
#  'cauchy',
#  'chi',
#  'chi2',
#  'chi2_contingency',
#  'chisquare',
#  'circmean',
#  'circstd',
#  'circvar',
#  'combine_pvalues',
#  'contingency',
#  'cosine',
#  'crystalball',
# ...

# %%
s = sp.randn(100)
print(len(s))
# Out:
# 100

# %%
print("Mean : {0:0.6f}".format(s.mean()))
# Out:
# Mean : -0.030041

# %%
A = sp.matrix([1,2,3,4]*2)
print(A)
# Out:
# [[1 2 3 4 1 2 3 4]]

# %%
c1,c2= 5.0,2.0
i = r_[1:11]
xi = 0.1*i
yi = c1*exp(-xi)+c2*xi
zi = yi + 0.05*max(yi)*random.randn(len(yi))

A = c_[exp(-xi)[:,newaxis],xi[:,newaxis]]
c,resid,rank,sigma = linalg.lstsq(A,zi)

xi2 = r_[0.1:1.0:100j]
yi2 = c[0]*exp(-xi2) + c[1]*xi2

plt.plot(xi,zi,'x',xi2,yi2)
plt.axes([0,1.1,3.0,5.5])
plt.xlabel('$x_i$')
plt.title('Data Fitting with linalg.lstsq')
plt.show()

# %%
n = 50
x = sp.linspace(-5,5,n)
a, b=0.8, -4
y = sp.polyval([a,b],x)
yn = y + sp.randn(n)
(ar,br) = sp.polyfit(x,yn,1)
yr=sp.polyval([ar,br],x)
err = sp.sqrt(sum((yr-yn)**2)/n)
print('Linear regression using polyfit')
print('Input parameters: a=%.2f b=%.2f' % (a,b))
print('Regression: a=%.2f b=%.2f, ms error= %.3f' % (ar,br,err)')
plt.title('Linear Regression Example')
plt.plot(x,y,'g--')
plt.plot(x,yn,'k.')
plt.plot(x,yr,'r-')
plt.legend(['original', 'plus noise', 'regression'])
plt.show()
# Out:
# Linear regression using polyfit
# Input parameters: a=0.80 b=-4.00
# Regression: a=0.94 b=-4.01, ms error= 0.895

# %%
(a_s,b_s,r,xx,stderr)=stats.linregress(x,yn)
print('Linear regression using stats.linregress')
print('Input parameters: a=%.2f b=%.2f' % (a,b))
print('Regression: a=%.2f b=%.2f, ms error= %.3f' % (a_s,b_s,stderr))
# Out:
# Linear regression using stats.linregress
# Input parameters: a=0.80 b=-4.00
# Regression: a=0.94 b=-4.01, ms error= 0.044

# %%
x = sp.linspace(0, 10*pi)
y = sp.cos(x)
z = exp(-x/10)*y
plt.title('Cosinus & exp')
plt.xlabel('x')
plt.ylabel('y=f(x)')
plt.plot(x,y,'g--')
plt.plot(x,z,'r')
plt.show()

# %%
t = sp.linspace(0,2*pi)
x = sp.sin(t) / (1+sp.cos(t)**2)
y = sp.sin(t)*sp.cos(t) / (1+cos(t)**2)
plt.title('Bernoulli')
plt.xlabel('x')
plt.ylabel('y=f(x)')
#plt.plot(t,x,'g--')
plt.plot(x,y,'r')
plt.show()

# %%
t = sp.linspace(0,10*pi)
x = sp.cos(t)*t
y = sp.sin(t)*t
plt.title('Archimède')
plt.xlabel('x')
plt.ylabel('y=f(x)')
#plt.plot(t,x,'g--')
plt.plot(x,y,'r')
plt.show()

# %%
t = sp.linspace(0,2*pi)
x = 16*sp.sin(t)**3
y = 13*sp.cos(t) - 5*cos(2*t) - 2*cos(3*t) - cos(4*t)
plt.title('La courbe de coeur')
plt.xlabel('x')
plt.ylabel('y=f(x)')
#plt.plot(t,x,'g--')
plt.plot(x,y,'r')
plt.show()

# %%
p,q=8,3
#p= random.randint(1,9)
#q= random.randint(1,9)
for i in range(1,9):
    t = sp.linspace(0,2*q*pi)
    x = (1+sp.cos(t*i/q))*cos(t)
    y = (1+sp.cos(t*i/q))*sin(t)
    plt.title('Les cyclo-harmoniques')
    plt.xlabel('x')
    plt.ylabel('y=f(x)')
    #plt.plot(t,x,'g--')
    plt.plot(x,y,'r')
    plt.show()
